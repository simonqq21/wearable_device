# %% [markdown]
# # Serial Receiver

# %%
import serial
import io
import numpy as np 
import os
from pathlib import Path
import struct
from cobs import cobs

# %%
ser = serial.Serial('/dev/ttyUSB0')
print(f"ser.name = {ser.name}")
# Out:
# ser.name = /dev/ttyUSB0

# %% [markdown]
# # Define orientation data struct

# %%
USE_EULER =  True
USE_QUATERNION = False 

if USE_EULER:
    # 1 uint64_t, 3 floats
    STRUCT_FORMAT = "<Q4f" 
elif USE_QUATERNION: 
    # 1 uint64_t, 4 floats
    STRUCT_FORMAT = "<Q4f"

struct_size = struct.calcsize(STRUCT_FORMAT) 
print(f"struct_size: {struct_size} bytes")
# Out:
# struct_size: 24 bytes

# %% [markdown]
# # Open serial port and

# %%
while True:
    with serial.Serial('/dev/ttyUSB0', 230400) as ser:
        in_data = ser.read_until(b'\0')
        # print(f"in_data = {in_data}") 
        
        # ser.read_until(b'0')
        # ser.read(1)
        
        in_data = b'' 
        while (len(in_data) < struct_size + 2):
            chunk = ser.read(struct_size + 2 - len(in_data))
            # print(f"len(chunk) = {len(chunk)}")
            in_data += chunk;
            
        # ser.read(1)
        # print(f"in_data = {in_data}") 
        # print(f"len(in_data) = {len(in_data)}")
        try:
            decoded = cobs.decode(in_data[:-1])
            # print(f"len(decoded) = {len(decoded)}")
            if (len(decoded) == struct_size):
                # Unpack the raw bytes into Python variables
                try:
                    unpacked_data = struct.unpack(STRUCT_FORMAT, decoded)
                    timestamp = unpacked_data[0] 
                    if USE_EULER:
                        x = unpacked_data[1]
                        y = unpacked_data[2] 
                        z = unpacked_data[3]
                        print(f"timestamp = {timestamp}, x = {x}, y = {y}, z = {z}")
                    elif USE_QUATERNION:
                        w = unpacked_data[1]
                        x = unpacked_data[2] 
                        y = unpacked_data[3]
                        z = unpacked_data[4]
                        print(f"timestamp = {timestamp}, w = {w}, x = {x}, y = {y}, z = {z}")
                except:
                    pass
        except:
            pass
# Out:
# timestamp = 279004, x = 30.0, y = 40.0, z = 50.0
# timestamp = 279121, x = 30.0, y = 40.0, z = 50.0
# timestamp = 279148, x = 30.0, y = 40.0, z = 50.0
# timestamp = 279409, x = 30.0, y = 40.0, z = 50.0
# timestamp = 279517, x = 30.0, y = 40.0, z = 50.0
# timestamp = 279733, x = 30.0, y = 40.0, z = 50.0
# timestamp = 279904, x = 30.0, y = 40.0, z = 50.0
# timestamp = 279931, x = 30.0, y = 40.0, z = 50.0
# timestamp = 280111, x = 30.0, y = 40.0, z = 50.0
# timestamp = 280228, x = 30.0, y = 40.0, z = 50.0
# timestamp = 280264, x = 30.0, y = 40.0, z = -2.5353012004564588e+32
# timestamp = 280444, x = 30.0, y = 40.0, z = 50.0
# timestamp = 280480, x = 30.0, y = 40.0, z = 2.3486468964925462e-36
# timestamp = 280705, x = 30.0, y = 40.0, z = 50.0
# timestamp = 280804, x = 30.0, y = 40.0, z = 50.0
# timestamp = 280831, x = 30.0, y = 40.0, z = 50.0
# timestamp = 281029, x = 30.0, y = 40.0, z = 50.0
# timestamp = 281047, x = 30.0, y = 40.0, z = 50.0
# timestamp = 281200, x = 30.0, y = 40.0, z = 50.0
# timestamp = 281335, x = 30.0, y = 40.0, z = 50.0
# timestamp = 281362, x = 30.0, y = 40.0, z = 50.0
# timestamp = 281605, x = 30.0, y = 40.0, z = 50.0
# timestamp = 281632, x = 30.0, y = 40.0, z = 50.0
# timestamp = 281704, x = 30.0, y = 40.0, z = 50.0
# timestamp = 281821, x = 30.0, y = 40.0, z = 50.0
# timestamp = 281866, x = 3.950288396900946e-40, y = 0.0, z = 30.0
# timestamp = 281965, x = 30.0, y = 40.0, z = 50.0
# timestamp = 282127, x = 30.0, y = 40.0, z = 50.0
# timestamp = 282154, x = 30.0, y = 40.0, z = 50.0
# timestamp = 282334, x = 30.0, y = 40.0, z = 50.0
# timestamp = 282460, x = 30.0, y = 40.0, z = 50.0
# timestamp = 282586, x = 30.0, y = 40.0, z = 50.0
# timestamp = 282604, x = 30.0, y = 40.0, z = 50.0
# timestamp = 282631, x = 30.0, y = 40.0, z = 50.0
# timestamp = 282802, x = 30.0, y = 40.0, z = 50.0
# timestamp = 282946, x = 30.0, y = 40.0, z = 50.0
# timestamp = 283054, x = 30.0, y = 40.0, z = 6.055403027917546e-39
# timestamp = 283288, x = 30.0, y = 40.0, z = 50.0
# timestamp = 283315, x = 30.0, y = 40.0, z = 50.0
# timestamp = 283504, x = 30.0, y = 40.0, z = 50.0
# timestamp = 283684, x = 30.0, y = 40.0, z = 50.0
# timestamp = 283783, x = 30.0, y = 40.0, z = 50.0
# timestamp = 283936, x = 30.0, y = 40.0, z = 50.0
# timestamp = 284080, x = 30.0, y = 40.0, z = 50.0
# timestamp = 284215, x = 30.0, y = 40.0, z = 50.0
# timestamp = 284359, x = 30.0, y = 40.0, z = 50.0
# timestamp = 284404, x = 30.0, y = 40.0, z = 50.0
# timestamp = 284521, x = 30.0, y = 40.0, z = 50.0
# timestamp = 284548, x = 30.0, y = 40.0, z = 50.0
# timestamp = 284818, x = 30.0, y = 40.0, z = 50.0
# timestamp = 284845, x = 30.0, y = 40.0, z = 50.0
# timestamp = 284953, x = 30.0, y = 40.0, z = 50.0
# timestamp = 285160, x = 30.0, y = 40.0, z = 50.0
# timestamp = 285277, x = 30.0, y = 40.0, z = 50.0
# timestamp = 285304, x = 30.0, y = 40.0, z = 50.0
# timestamp = 285412, x = 30.0, y = 40.0, z = 50.0
# timestamp = 285439, x = 30.0, y = 40.0, z = 50.0
# timestamp = 285592, x = 30.0, y = 40.0, z = 50.0
# timestamp = 285808, x = 30.0, y = 40.0, z = 50.0
# timestamp = 285970, x = 30.0, y = 40.0, z = 50.0
# timestamp = 286114, x = 30.0, y = 40.0, z = 50.0
# timestamp = 17509995351216774607, x = 1.5652503846508207e-42, y = 0.0, z = 6.055403027917546e-39
# timestamp = 286303, x = 30.0, y = 40.0, z = 50.0
# timestamp = 286411, x = 30.0, y = 40.0, z = 50.0
# timestamp = 286501, x = 30.0, y = 40.0, z = 50.0
# timestamp = 286744, x = 30.0, y = 40.0, z = 50.0
# timestamp = 286771, x = 30.0, y = 40.0, z = 50.0
# timestamp = 286996, x = 30.0, y = 40.0, z = 50.0
# timestamp = 287104, x = 30.0, y = 40.0, z = 50.0
# timestamp = 287203, x = 30.0, y = 40.0, z = 50.0
# timestamp = 287230, x = 30.0, y = 40.0, z = 50.0
# timestamp = 287428, x = 30.0, y = 40.0, z = 50.0
# timestamp = 287635, x = 30.0, y = 40.0, z = 50.0
# timestamp = 287842, x = 30.0, y = 40.0, z = 50.0
# timestamp = 287977, x = 30.0, y = 40.0, z = 50.0
# timestamp = 288004, x = 30.0, y = 40.0, z = 50.0
# timestamp = 288211, x = 30.0, y = 40.0, z = 50.0
# timestamp = 288238, x = 30.0, y = 40.0, z = 50.0
# timestamp = 288427, x = 30.0, y = 40.0, z = 50.0
# timestamp = 288643, x = 30.0, y = 40.0, z = 50.0
# timestamp = 288904, x = 30.0, y = 40.0, z = 50.0
# timestamp = 288931, x = 30.0, y = 40.0, z = 50.0
# timestamp = 289111, x = 30.0, y = 40.0, z = 50.0
# timestamp = 289192, x = 30.0, y = 40.0, z = 50.0
# timestamp = 289435, x = 30.0, y = 40.0, z = 50.0
# timestamp = 289696, x = 30.0, y = 40.0, z = 50.0
# timestamp = 289804, x = 30.0, y = 40.0, z = 50.0
# timestamp = 289831, x = 30.0, y = 40.0, z = 50.0
# timestamp = 290020, x = 30.0, y = 40.0, z = 50.0
# timestamp = 290092, x = 30.0, y = 40.0, z = 50.0
# timestamp = 290290, x = 30.0, y = 40.0, z = 50.0
# timestamp = 290479, x = 30.0, y = 40.0, z = 50.0
# timestamp = 290668, x = 30.0, y = 40.0, z = 50.0
# timestamp = 290704, x = 30.0, y = 40.0, z = 50.0
# timestamp = 290731, x = 30.0, y = 40.0, z = 50.0
# timestamp = 290911, x = 30.0, y = 40.0, z = 50.0
# timestamp = 290938, x = 30.0, y = 40.0, z = 50.0
# timestamp = 291001, x = 30.0, y = 40.0, z = 50.0
# timestamp = 291163, x = 30.0, y = 40.0, z = 50.0
# timestamp = 291298, x = 30.0, y = 40.0, z = 50.0
# timestamp = 291424, x = 30.0, y = 40.0, z = 50.0
# timestamp = 291451, x = 30.0, y = 40.0, z = 50.0
# timestamp = 291604, x = 30.0, y = 40.0, z = 50.0
# timestamp = 291631, x = 30.0, y = 40.0, z = 50.0
# timestamp = 291703, x = 30.0, y = 40.0, z = 50.0
# timestamp = 291739, x = 30.0, y = 40.0, z = 50.0
# timestamp = 291847, x = 30.0, y = 40.0, z = 50.0
# timestamp = 292063, x = 30.0, y = 40.0, z = 50.0
# timestamp = 292090, x = 30.0, y = 40.0, z = 6.055403027917546e-39
# timestamp = 292234, x = 30.0, y = 40.0, z = 50.0
# timestamp = 292270, x = 30.0, y = 2.938735877055719e-38, z = 0.0
# timestamp = 292504, x = 30.0, y = 40.0, z = 50.0
# timestamp = 292531, x = 30.0, y = 40.0, z = 50.0
# timestamp = 292702, x = 30.0, y = 40.0, z = 50.0
# timestamp = 292963, x = 30.0, y = 40.0, z = 50.0
# timestamp = 293071, x = 30.0, y = 40.0, z = 50.0
# timestamp = 293233, x = 30.0, y = 40.0, z = 50.0
# timestamp = 293404, x = 30.0, y = 40.0, z = 50.0
# timestamp = 293431, x = 30.0, y = 40.0, z = 50.0
# timestamp = 293602, x = 30.0, y = 40.0, z = 50.0
# timestamp = 293836, x = 30.0, y = 40.0, z = 50.0
# timestamp = 293944, x = 30.0, y = 40.0, z = 50.0
# timestamp = 294178, x = 30.0, y = 40.0, z = 50.0
# timestamp = 294259, x = 30.0, y = 40.0, z = 2.9809342875403157e-36
# timestamp = 294331, x = 30.0, y = 40.0, z = 50.0
# timestamp = 294529, x = 30.0, y = 40.0, z = 50.0
# timestamp = 294601, x = 30.0, y = 40.0, z = 50.0
# timestamp = 294718, x = 30.0, y = 40.0, z = 50.0
# timestamp = 294835, x = 30.0, y = 40.0, z = 50.0
# timestamp = 294871, x = 30.0, y = 40.0, z = 50.0
# timestamp = 295105, x = 30.0, y = 40.0, z = 50.0
# timestamp = 295204, x = 30.0, y = 40.0, z = 50.0
# timestamp = 295231, x = 30.0, y = 40.0, z = 50.0
# timestamp = 295411, x = 30.0, y = 40.0, z = 50.0
# timestamp = 295438, x = 30.0, y = 40.0, z = 50.0
# timestamp = 295636, x = 30.0, y = 40.0, z = 50.0
# timestamp = 295753, x = 30.0, y = 40.0, z = 50.0
# timestamp = 295780, x = 30.0, y = 40.0, z = 50.0
# timestamp = 296023, x = 30.0, y = 40.0, z = 50.0
# timestamp = 144115188076152057, x = 1.6213023232238134e-42, y = 0.0, z = 6.055403027917546e-39
# timestamp = 296347, x = 30.0, y = 40.0, z = 50.0
# timestamp = 296500, x = 30.0, y = 40.0, z = 50.0
# timestamp = 296671, x = 30.0, y = 40.0, z = 50.0
# timestamp = 296707, x = 8.816207631167156e-38, y = 0.0, z = 6.055403027917546e-39
# timestamp = 296941, x = 30.0, y = 40.0, z = 50.0
# timestamp = 297004, x = 30.0, y = 40.0, z = 50.0
# timestamp = 297040, x = 30.0, y = 40.0, z = 50.0
# timestamp = 297238, x = 30.0, y = 40.0, z = 50.0
# timestamp = 297454, x = 30.0, y = 40.0, z = 50.0
# timestamp = 297553, x = 30.0, y = 40.0, z = 50.0
# timestamp = 297598, x = 4.170740671308526e-40, y = 0.0, z = 30.0
# timestamp = 297823, x = 30.0, y = 40.0, z = 50.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 11
#       7         # ser.read(1)
#       8
#       9         in_data = b''
#      10         while (len(in_data) < struct_size + 2):
# ---> 11             chunk = ser.read(struct_size + 2 - len(in_data))
#      12             # print(f"len(chunk) = {len(chunk)}")
#      13             in_data += chunk;
#      14
#
# File ~/.local/lib/python3.12/site-packages/serial/serialposix.py:565, in Serial.read(self, size)
#     563 while len(read) < size:
#     564     try:
# --> 565         ready, _, _ = select.select([self.fd, self.pipe_abort_read_r], [], [], timeout.time_left())
#     566         if self.pipe_abort_read_r in ready:
#     567             os.read(self.pipe_abort_read_r, 1000)
#
# KeyboardInterrupt:
